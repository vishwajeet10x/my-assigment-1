# %% [markdown]
# <h1>My Jupter Notebook on IMB Watson Studio</h1>

# %% [markdown]
# **VISHWAJEET SINGH**

# %% [markdown]
# Student

# %% [markdown]
# *I am interested in data science because i want to build my career in finace as data scientest*

# %% [markdown]
# multiply two number

# %%
num_1 = 5
num_2 = 4
product = num_1 * num_2 
print("product of {} and {} is {}".format(num_1, num_2,product))
# Out:
# product of 5 and 4 is 20

# %% [markdown]
# |S.no||month||expense|
# |---||---||---|
# |- 1||may||25000|
# |- 2||june||20000|
# |- 3||july||30000|
#
# - one
# - two
# - three
# - four
#
# www.ibm.com
